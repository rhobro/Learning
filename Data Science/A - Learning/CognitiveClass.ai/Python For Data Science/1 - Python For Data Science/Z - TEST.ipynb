# %%
import numpy as np

X_values = [0, 20, 40, 60, 80, 100, 120]
y_values = [25.0, 20.8, 17.4, 14.5, 12.1, 10.0, 8.4]

from matplotlib import pyplot as plt
plt.plot(np.unique(X_values), np.poly1d(np.polyfit(X_values, y_values, 1))(np.unique(X_values)))
